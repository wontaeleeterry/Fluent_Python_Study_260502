# %%
class NumberDescriptor:
    def __set_name__(self, owner, name):
        self.storage_name = f"_{name}"

    def __get__(self, instance, owner):
        if instance is None:
            return self

        return getattr(instance, self.storage_name)

    def __set__(self, instance, value):
        if value > 0:
            setattr(instance, self.storage_name, value)
        else:
            raise ValueError(
                f"{self.storage_name}에는 양수만 입력할 수 있습니다."
            )


class Calculator:
    value1 = NumberDescriptor()
    value2 = NumberDescriptor()

    def __init__(self, value1, value2):
        self.value1 = value1
        self.value2 = value2

    def multiply(self):
        return self.value1 * self.value2

# %%
calc = Calculator(10, 20)

# %%
result = calc.multiply()
print(result)

# %%
# 예외 발생
calc_error = Calculator(0, 10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 # 예외 발생
# ----> 2 calc_error = Calculator(0, 10)
#
# Cell In[2], line 25, in Calculator.__init__(self, value1, value2)
#      24     def __init__(self, value1, value2):
# ---> 25         self.value1 = value1
#      26         self.value2 = value2
#
# Cell In[2], line 15, in NumberDescriptor.__set__(self, instance, value)
#      11     def __set__(self, instance, value):
#      12         if value > 0:
#      13             setattr(instance, self.storage_name, value)
#      14         else:
# ---> 15             raise ValueError(
#      16                 f"{self.storage_name}에는 양수만 입력할 수 있습니다."
#      17             )
#
# ValueError: _value1에는 양수만 입력할 수 있습니다.
